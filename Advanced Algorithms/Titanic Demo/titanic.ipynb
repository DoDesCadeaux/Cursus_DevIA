# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/bdemeshev/om_metrics/master/datasets/titanic3.csv'

data = pd.read_csv(url)
data
# Out:
#       Unnamed: 0 pclass  survived                             name     sex  \
# 0              1    1st         1    Allen, Miss. Elisabeth Walton  female
# 1              2    1st         1   Allison, Master. Hudson Trevor    male
# 2              3    1st         0     Allison, Miss. Helen Loraine  female
# 3              4    1st         0  Allison, Mr. Hudson Joshua Crei    male
# 4              5    1st         0  Allison, Mrs. Hudson J C (Bessi  female
# ...          ...    ...       ...                              ...     ...
# 1304        1305    3rd         0             Zabour, Miss. Hileni  female
# 1305        1306    3rd         0            Zabour, Miss. Thamine  female
# 1306        1307    3rd         0        Zakarian, Mr. Mapriededer    male
# 1307        1308    3rd         0              Zakarian, Mr. Ortin    male
# 1308        1309    3rd         0               Zimmerman, Mr. Leo    male
#
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean    655.000000     0.381971    29.881135     0.498854     0.385027
# std     378.020061     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%     328.000000     0.000000    21.000000     0.000000     0.000000
# 50%     655.000000     0.000000    28.000000     0.000000     0.000000
# 75%     982.000000     1.000000    39.000000     1.000000     0.000000
# max    1309.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758669   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329224  328.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1309 non-null   int64
#  1   pclass      1309 non-null   object
#  2   survived    1309 non-null   int64
#  3   name        1309 non-null   object
#  4   sex         1309 non-null   object
#  5   age         1046 non-null   float64
#  6   sibsp       1309 non-null   int64
#  7   parch       1309 non-null   int64
#  8   ticket      1309 non-null   object
#  9   fare        1308 non-null   float64
#  10  cabin       295 non-null    object
#  11  embarked    1307 non-null   object
#  12  boat        486 non-null    object
#  13  body        121 non-null    float64
#  14  home.dest   745 non-null    object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 153.5+ KB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')

# %%
sns.heatmap(data.isna().T, cbar=False)
plt.title('Null Values')
plt.show()

# %%
data.shape
# Out:
# (1309, 15)

# %%
data['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['cabin'].unique()
# Out:
# array(['B5', 'C22 C26', 'E12', 'D7', 'A36', 'C101', nan, 'C62 C64', 'B35',
#        'A23', 'B58 B60', 'D15', 'C6', 'D35', 'C148', 'C97', 'B49', 'C99',
#        'C52', 'T', 'A31', 'C7', 'C103', 'D22', 'E33', 'A21', 'B10', 'B4',
#        'E40', 'B38', 'E24', 'B51 B53 B55', 'B96 B98', 'C46', 'E31', 'E8',
#        'B61', 'B77', 'A9', 'C89', 'A14', 'E58', 'E49', 'E52', 'E45',
#        'B22', 'B26', 'C85', 'E17', 'B71', 'B20', 'A34', 'C86', 'A16',
#        'A20', 'A18', 'C54', 'C45', 'D20', 'A29', 'C95', 'E25', 'C111',
#        'C23 C25 C27', 'E36', 'D34', 'D40', 'B39', 'B41', 'B102', 'C123',
#        'E63', 'C130', 'B86', 'C92', 'A5', 'C51', 'B42', 'C91', 'C125',
#        'D10 D12', 'B82 B84', 'E50', 'D33', 'C83', 'B94', 'D49', 'D45',
#        'B69', 'B11', 'E46', 'C39', 'B18', 'D11', 'C93', 'B28', 'C49',
#        'B52 B54 B56', 'E60', 'C132', 'B37', 'D21', 'D19', 'C124', 'D17',
#        'B101', 'D28', 'D6', 'D9', 'B80', 'C106', 'B79', 'C47', 'D30',
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# pclass         object
# survived        int64
# name           object
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# ticket         object
# fare          float64
# cabin          object
# embarked       object
# boat           object
# body          float64
# home.dest      object
# dtype: object

# %%
data_numerical = data.select_dtypes(include='number')
data_categorical = data.select_dtypes(include='object')
data_categorical
# Out:
#      pclass                             name     sex  ticket    cabin  \
# 0       1st    Allen, Miss. Elisabeth Walton  female   24160       B5
# 1       1st   Allison, Master. Hudson Trevor    male  113781  C22 C26
# 2       1st     Allison, Miss. Helen Loraine  female  113781  C22 C26
# 3       1st  Allison, Mr. Hudson Joshua Crei    male  113781  C22 C26
# 4       1st  Allison, Mrs. Hudson J C (Bessi  female  113781  C22 C26
# ...     ...                              ...     ...     ...      ...
# 1304    3rd             Zabour, Miss. Hileni  female    2665      NaN
# 1305    3rd            Zabour, Miss. Thamine  female    2665      NaN
# 1306    3rd        Zakarian, Mr. Mapriededer    male    2656      NaN
# 1307    3rd              Zakarian, Mr. Ortin    male    2670      NaN
# 1308    3rd               Zimmerman, Mr. Leo    male  315082      NaN
#
#          embarked boat                        home.dest
# 0     Southampton    2                     St Louis, MO
# ...

# %%
survival_sex = data.groupby(['sex', 'survived']).size().unstack()
survival_sex.plot(kind='bar', stacked=True)
plt.title('Survived')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
data_copy = data.copy()

data_copy[['sex', 'pclass']] = OrdinalEncoder().fit_transform(data_copy[['sex', 'pclass']])

# %%
df = data_copy.loc[:, ['sex', 'age', 'pclass', 'survived']]
df
# Out:
#       sex      age  pclass  survived
# 0     0.0  29.0000     0.0         1
# 1     1.0   0.9167     0.0         1
# 2     0.0   2.0000     0.0         0
# 3     1.0  30.0000     0.0         0
# 4     0.0  25.0000     0.0         0
# ...   ...      ...     ...       ...
# 1304  0.0  14.5000     2.0         0
# 1305  0.0      NaN     2.0         0
# 1306  1.0  26.5000     2.0         0
# 1307  1.0  27.0000     2.0         0
# 1308  1.0  29.0000     2.0         0
#
# [1309 rows x 4 columns]
