# %%
import pandas as pd

# %%
data = pd.read_csv('data/Exercices_Pandas_athlete_events.csv')
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data.shape
# Out:
# (271116, 15)

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
int(data.isnull().sum().sum())
# Out:
# 363853

# %%
data['Games']
# Out:
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# 4         1988 Winter
#              ...
# 271111    1976 Winter
# 271112    2014 Winter
# 271113    2014 Winter
# 271114    1998 Winter
# 271115    2002 Winter
# Name: Games, Length: 271116, dtype: object

# %%
data['Name'].str.strip().sort_values()
# Out:
# 0                        A Dijiang
# 1                         A Lamusi
# 153340    A. Aanantha Sambu Mayavo
# 528                A. Abdul Razzak
# 529                A. Abdul Razzak
#                     ...
# 114964                   zlem Kaya
# 79870                   zman Graud
# 207676                  zzet Safer
# 102956                    zzet nce
# 102955                    zzet nce
# Name: Name, Length: 271116, dtype: object

# %%
data[['Event', 'City', 'Name', 'Medal']]
# Out:
#                                            Event            City  \
# 0                    Basketball Men's Basketball       Barcelona
# 1                   Judo Men's Extra-Lightweight          London
# 2                        Football Men's Football       Antwerpen
# 3                    Tug-Of-War Men's Tug-Of-War           Paris
# 4               Speed Skating Women's 500 metres         Calgary
# ...                                          ...             ...
# 271111                Luge Mixed (Men)'s Doubles       Innsbruck
# 271112  Ski Jumping Men's Large Hill, Individual           Sochi
# 271113        Ski Jumping Men's Large Hill, Team           Sochi
# 271114                      Bobsleigh Men's Four          Nagano
# 271115                      Bobsleigh Men's Four  Salt Lake City
#
#                             Name Medal
# 0                      A Dijiang   NaN
# 1                       A Lamusi   NaN
# 2            Gunnar Nielsen Aaby   NaN
# ...

# %%
data.iloc[0:25]
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %%
data = pd.read_csv('data/Exercices_Pandas_athlete_events.csv')
football = data[data["Sport"] == 'Football']
football_2 = data[data["Sport"].isin(['Football'])]
football, football_2
# Out:
# (            ID                               Name Sex   Age  Height  Weight  \
#  2            3                Gunnar Nielsen Aaby   M  24.0     NaN     NaN
#  105         37                 Ann Kristin Aarnes   F  23.0   182.0    64.0
#  116         41                           Rolf Aas   M  28.0     NaN     NaN
#  157         61                   Stefan Abadzhiev   M  26.0   175.0    72.0
#  178         76         Jouan Patrice Abanda Etong   M  22.0   185.0    82.0
#  ...        ...                                ...  ..   ...     ...     ...
#  270810  135438               Manuel Ziga Fernndez   M  20.0   172.0    69.0
#  270843  135455                    Vjekoslav upani   M  19.0     NaN     NaN
#  270901  135476                  Emily Jane Zurrer   F  21.0   179.0    69.0
#  270982  135504  Viktor Oleksandrovych Zviahintsev   M  25.0   178.0    79.0
#  271107  135566         James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
# ...

# %%
ete = data[data["Season"] == 'Summer']
ete
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
hiver = data[data["Season"] == "Winter"]
hiver
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
data['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
specific_names = data[(data['Name'].str.contains('Owens')) | (data['Name'].str.contains('Jesse'))]
specific_names
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 14038     7587   Kenneth Owens "Ken" Bantum   M  21.0   198.0   106.0
# 35531    18266  Jesse Landis "Lee" Carleton   M  41.0     NaN     NaN
# 35532    18266  Jesse Landis "Lee" Carleton   M  41.0     NaN     NaN
# 43016    22182                Jesse Cockney   M  24.0   180.0    76.0
# 43017    22182                Jesse Cockney   M  24.0   180.0    76.0
# ...        ...                          ...  ..   ...     ...     ...
# 256091  128225     Jesse Alfred Wallingford   M  36.0     NaN     NaN
# 256092  128225     Jesse Alfred Wallingford   M  36.0     NaN     NaN
# 260999  130612        Jesse Daniel Williams   M  24.0   184.0    80.0
# 261000  130612        Jesse Daniel Williams   M  28.0   184.0    80.0
# 262755  131475            Harvey Jesse Wood   M  23.0   193.0    89.0
#
#                                     Team  NOC        Games  Year  Season  \
# ...

# %%
specific_names.value_counts('Event')
# Out:
# Event
# Water Polo Men's Water Polo                     4
# Gymnastics Men's Horizontal Bar                 3
# Gymnastics Men's Floor Exercise                 3
# Sailing Men's Two Person Dinghy                 3
# Rowing Men's Single Sculls                      3
#                                                ..
# Swimming Men's 200 metres Backstroke            1
# Volleyball Women's Volleyball                   1
# Swimming Men's 400 metres Individual Medley     1
# Wrestling Men's Featherweight, Greco-Roman      1
# Wrestling Men's Super-Heavyweight, Freestyle    1
# Name: count, Length: 66, dtype: int64

# %%
data.value_counts('Sex')
# Out:
# Sex
# M    196594
# F     74522
# Name: count, dtype: int64

# %%
min_age = data['Age'].idxmin()
youngest = data.loc[min_age]
youngest
# Out:
# ID                                        71691
# Name                         Dimitrios Loundras
# Sex                                           M
# Age                                        10.0
# Height                                      NaN
# Weight                                      NaN
# Team              Ethnikos Gymnastikos Syllogos
# NOC                                         GRE
# Games                               1896 Summer
# Year                                       1896
# Season                                   Summer
# City                                     Athina
# Sport                                Gymnastics
# Event     Gymnastics Men's Parallel Bars, Teams
# Medal                                    Bronze
# Name: 142882, dtype: object

# %%
oldest = data[data['Age'] == data['Age'].max()]
oldest
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
badminton = data[(data['Event'] == "Badminton Men's Singles") | (data['Event'] == "Badminton Women's Singles")]
badminton_winners = badminton[badminton['Medal'] == 'Gold']
badminton_winners = badminton_winners['Name'].sort_values()
badminton_winners
# Out:
# 31409          Alexander Alan Budikusuma Wiratama
# 13855                               Bang Su-Hyeon
# 149622                    Carolina Mara Marn Marn
# 39337                                   Chen Long
# 81604                                Gong Zhichao
# 108331                                 Ji Xinpeng
# 138456                                  Li Xuerui
# 139311                                    Lin Dan
# 139312                                    Lin Dan
# 232573    Lucia Francisca "Susi" Susanti Haditono
# 99666         Poul-Erik Hyer Larsen (-Engel Hyer)
# 95679                              Taufik Hidayat
# 268880                                 Zhang Ning
# 268881                                 Zhang Ning
# Name: Name, dtype: object

# %%
b_1984_2016 = data[(data['Year'] >= 1984) & (data['Year'] <= 2016)]
data_medals = b_1984_2016[b_1984_2016['Medal'].notna()]
medal_count = data_medals['Team'].value_counts()
top_3 = medal_count.head(3)
top_3
# Out:
# Team
# United States    2672
# Germany          1185
# Russia           1100
# Name: count, dtype: int64

# %%
data_w_m = data[(data['Year'] == 2016)]
men = data_w_m[data_w_m['Sex'] == 'M']
women = data_w_m[data_w_m['Sex'] == 'F']
nb_women = women.shape[0]
nb_men = men.shape[0]
nb_men, nb_women
# Out:
# (7465, 6223)

# %%
belgium = data[data['NOC'] == 'BEL']
belgium_medals = belgium[belgium['Medal'].notna()].shape[0]
belgium_medals
# Out:
# 468

# %%
gold = belgium[belgium['Medal'] == 'Gold']
event_gold = gold['Event'].unique()
event_gold
# Out:
# array(["Archery Men's Target Archery, 33 metres, Team",
#        "Archery Men's Target Archery, 50 metres, Team",
#        "Fencing Men's epee, Team", "Fencing Men's epee, Individual",
#        "Football Men's Football", 'Figure Skating Mixed Pairs',
#        "Equestrianism Men's Vaulting, Individual",
#        "Equestrianism Men's Vaulting, Team", 'Sailing Mixed 6 metres',
#        "Archery Men's Pole Archery, Large Birds, Individual",
#        "Archery Men's Pole Archery, Small Birds, Team",
#        "Archery Men's Pole Archery, Large Birds, Team",
#        'Art Competitions Mixed Sculpturing',
#        "Weightlifting Men's Featherweight",
#        "Cycling Men's Road Race, Team",
#        "Swimming Men's 100 metres Breaststroke",
#        "Boxing Men's Welterweight",
#        "Archery Men's Sur La Perche a La Herse",
#        "Cycling Men's 50 kilometres",
#        'Equestrianism Mixed Jumping, Individual',
#        "Athletics Women's High Jump", "Tennis Women's Singles",
# ...

# %%
belgium = data[data['NOC'] == 'BEL']
belgium_medals = belgium[belgium['Medal'].notna()].value_counts().groupby('Year').sum()
best_year = belgium_medals.tail(1)
best_year
# Out:
# Year
# 2016    21
# Name: count, dtype: int64

# %%
women_athletics = data[(data['Sport'] == 'Athletics') & (data['Sex'] == 'F')]
gold_women_athletics = women_athletics[women_athletics['Medal'] == 'Gold']
data_gold_women_athletics = gold_women_athletics[['Year', 'Event', 'Name', 'NOC']]
data_gold_women_athletics
# Out:
#         Year                                   Event  \
# 1527    2008              Athletics Women's Shot Put
# 1528    2012              Athletics Women's Shot Put
# 2815    1996             Athletics Women's Long Jump
# 3020    2016  Athletics Women's 4 x 100 metres Relay
# 6764    2000  Athletics Women's 4 x 400 metres Relay
# ...      ...                                     ...
# 268293  1972            Athletics Women's 400 metres
# 268294  1972  Athletics Women's 4 x 400 metres Relay
# 270104  1980  Athletics Women's 4 x 400 metres Relay
# 270970  2000          Athletics Women's Discus Throw
# 271076  1952              Athletics Women's Shot Put
#
#                                              Name  NOC
# 1527         Valerie Kasanita Adams-Vili (-Price)  NZL
# 1528         Valerie Kasanita Adams-Vili (-Price)  NZL
# 2815                       Chioma Ajunwa (-Opara)  NGR
# 3020                            Morolake Akinosun  USA
# ...

# %%
sports_per_year = data[data['Sport'].notna()].groupby('Year')['Sport'].nunique()
sports_per_year
# Out:
# Year
# 1896     9
# 1900    20
# 1904    18
# 1906    13
# 1908    24
# 1912    17
# 1920    25
# 1924    30
# 1928    25
# 1932    25
# 1936    32
# 1948    29
# 1952    27
# 1956    27
# 1960    27
# 1964    31
# 1968    30
# 1972    33
# 1976    33
# 1980    33
# 1984    35
# 1988    37
# 1992    41
# 1994    12
# 1996    31
# 1998    14
# 2000    34
# 2002    15
# 2004    34
# 2006    15
# 2008    34
# 2010    15
# 2012    32
# 2014    15
# 2016    34
# Name: Sport, dtype: int64

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
country_medals = data[data['Medal'].notna()].groupby('NOC')['Medal'].size()
best_country = country_medals.sort_values(ascending=False)
top_15 = best_country.head(15)
top_15
# Out:
# NOC
# USA    5637
# URS    2503
# GER    2165
# GBR    2068
# FRA    1777
# ITA    1637
# SWE    1536
# CAN    1352
# AUS    1320
# RUS    1165
# HUN    1135
# NED    1040
# NOR    1033
# GDR    1005
# CHN     989
# Name: Medal, dtype: int64

# %%
noc_participate = data[data['Medal'].notna()].groupby(['Sport', 'NOC']).size()
medals_per_sport = noc_participate.groupby('Sport').idxmax()
medals_per_sport
# Out:
# Sport
# Aeronautics              (Aeronautics, SUI)
# Alpine Skiing          (Alpine Skiing, AUT)
# Alpinism                    (Alpinism, GBR)
# Archery                      (Archery, KOR)
# Art Competitions    (Art Competitions, GER)
#                              ...
# Tug-Of-War                (Tug-Of-War, GBR)
# Volleyball                (Volleyball, URS)
# Water Polo                (Water Polo, HUN)
# Weightlifting          (Weightlifting, URS)
# Wrestling                  (Wrestling, USA)
# Length: 66, dtype: object

# %%
cold_war = data[(data['Year'] >= 1952) & (data['Year'] <= 1988)]
all_countries = cold_war[cold_war['NOC'].notna()]
medals_per_country = all_countries.groupby(by='NOC', as_index=False).agg({'Medal': 'count'})

athletes_per_country = all_countries.groupby(by='NOC', as_index=False).agg({'ID': 'count'})

efficacity['Medals_per_Athletes'] = medals_per_country['Medal'] / athletes_per_country['ID']
display(medals_per_country)
display(athletes_per_country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 7
#       3 medals_per_country = all_countries.groupby(by='NOC', as_index=False).agg({'Medal': 'count'})
#       5 athletes_per_country = all_countries.groupby(by='NOC', as_index=False).agg({'ID': 'count'})
# ----> 7 efficacity['Medals_per_Athletes'] = medals_per_country['Medal'] / athletes_per_country['ID']
#       8 display(medals_per_country)
#       9 display(athletes_per_country)
#
# NameError: name 'efficacity' is not defined
